# %% [markdown]
# It's been almost a year since Hurricane Maria slammed into Puerto Rico. There are still people without a safe roof over their heads and electricity in their houses. However, islanders will always find the beach to be the place where they can let go of all worries and enjoy quality time. Beaches in Puerto Rico are a main attraction for foreigners and locals since they are warm all year round. Yet one cannot forget that the environment impacts of a category four hurricane does not disappear in a short period of time. On the island all the rivers went out of their channel and dragged debris and dead animals for months. This project intends to answer the questions of many locals and visitors have:
#
# Are Puerto Rican beaches in a good state after Maria or the data says something different?
# What’s the beach water quality of the most visited beaches?
# Has the hurricane have a life long impact on beach water quality?

# %% [markdown]
# Some Beaches included in water monitoring system in Puerto Rico
# • Balneario El Escambrón - San Juan
# • Balneario de Carolina
# • Balneario Monserrate - Luquillo·
# • Playa Flamenco - Culebra
# • Balneario Punta Santiago - Humacao
# • Balneario Seven Seas - Fajardo
# • Balneario Punta Aguilarte - Arroyo
# • Balneario de Patillas
# • Playa Buyé - Cabo Rojo
# • Balneario de Rincón - Rincón
# • Balneario Caña Gorda - Guánica
# • Balneario Boquerón - Cabo Rojo
# • Playa Combate - Cabo Rojo
# • Balneario Puerto Nuevo - Vega Baja
# • Playa Santa - Guánica
# • Balneario de Añasco - Añasco
# • Playa Moja Casabe - Cabo Rojo
# • Balneario Crash Boat - Aguadilla
# • Balneario Cerro Gordo -Vega Alta
# • Balneario Sardinera - Dorado
# • Balneario Punta Salinas - Toa Baja·
# • Balneario Pico de Piedra - Aguada
# • Balneario Sun Bay - Vieques

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from cycler import cycler
# %matplotlib inline
import seaborn as sns

# %%
plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'font.family': 'sans-serif',
    'font.sans-serif' : 'Tahoma',
    'axes.facecolor' : '#ffffff',
    'axes.axisbelow':True, 
    'axes.grid' : True,
    'grid.color' : '#bec0c2',
    'grid.linestyle' : 'dotted',
    'axes.spines.left'   : False,   
    'axes.spines.bottom' : False,
    'axes.spines.top'    : False,
    'axes.spines.right' : False,
    'axes.prop_cycle': cycler('color', ['chartreuse','mediumseagreen','mediumaquamarine','mediumturquoise','cadetblue','skyblue','teal',
                                        'mediumspringgreen','seagreen']),
    'xtick.bottom'  : False,
    'ytick.left': False,
    'figure.titlesize' : 'large', 
    'figure.titleweight' : 'bold',
    'figure.facecolor' : '#ffffff',
    'text.color' : '#595959',
    'axes.labelcolor' : '#595959',
    'xtick.color' : '#595959',
    'ytick.color' : '#595959',
    'legend.loc' : 'best',
    'legend.fancybox'    : True,
    'legend.frameon'     : True,
    'legend.edgecolor'     : '0.9',
    'legend.markerscale'   : '0.5',
    'lines.marker'      : None,
    'lines.markersize'  : 3,           
})

# %%
playas=pd.read_csv('Monitoreo de Playas 2018.csv')
playas.head()
# Out:
#          Date Beach ID                                    Beach Name  \
# 0  2015-01-07    RW-18  Balneario Manuel “Nolo” Morales or Sardinera
# 1  2015-01-07    RW-19                       Balneario Punta Salinas
# 2  2015-01-07   RW-20A                        Balneario El Escambrón
# 3  2015-01-07   RW-21C                         Balneario de Carolina
# 4  2015-01-07   RW-25A                           Playa Sixto Escobar
#
#                   Latitude Longitude Sampling Route Sampling Type  \
# 0  Route 1: Dorado - Loíza   Routine            240            24
# 1  Route 1: Dorado - Loíza   Routine              8             1
# 2  Route 1: Dorado - Loíza   Routine              1             1
# 3  Route 1: Dorado - Loíza   Routine              1             1
# 4  Route 1: Dorado - Loíza   Routine            240            24
#
#   Enterococcus\r\n (colonies/100 mL) Temperature\r\n(°C)  \
# 0                              23.90           8.16/8.15
# 1                              25.00                8.13
# 2                              24.60                8.08
# 3                              25.30                8.12
# 4                              24.50                8.03
#
#                                          pH  Observations
# 0  The information provided is preliminary .          NaN
# 1  The information provided is preliminary .          NaN
# 2  The information provided is preliminary .          NaN
# 3  The information provided is preliminary .          NaN
# 4  The information provided is preliminary .          NaN

# %%
playas.tail()
# Out:
#             Date Beach ID                                       Beach Name  \
# 3441  2018-12-10    RW-16                             Balneario Crash Boat
# 3442  2018-12-11    RW-38                                Muelle de Arecibo
# 3443  2018-12-11    RW-39                                     Mar Chiquita
# 3444  2018-12-11    RW-23                        Balneario de Puerto Nuevo
# 3445  2018-12-11    RW-17  Balneario Cerro Gordo or Javier Calderón Nieves
#
#         Latitude    Longitude                  Sampling Route Sampling Type  \
# 3441  18.4576667  -67.1637778     Route 5: Añasco - Aguadilla       Routine
# 3442  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 3443  18.4729167  -66.4856556  Route: 6: Arecibo – Vega Alta        Routine
# 3444  18.4913667  -66.3990444  Route: 6: Arecibo – Vega Alta        Routine
# 3445  18.4812500  -66.3406556  Route: 6: Arecibo – Vega Alta        Routine
#
#      Enterococcus\r\n (colonies/100 mL) Temperature\r\n(°C)   pH  Observations
# 3441                                <10                28.2  8.25          NaN
# 3442                                 30                27.3  8.08          NaN
# 3443                                <10                27.5   8.2          NaN
# 3444                                <10                27.4  8.15          NaN
# 3445                                 31                25.5  8.16          NaN

# %%
playas.shape
# Out:
# (3446, 11)

# %%
playas.columns
# Out:
# Index(['Date', 'Beach ID', 'Beach Name', 'Latitude', 'Longitude',
#        'Sampling Route', 'Sampling Type', 'Enterococcus\r\n (colonies/100 mL)',
#        'Temperature\r\n(°C)', 'pH ', 'Observations'],
#       dtype='object')

# %%
playas['Date']=playas['Date'].str.extract(r'(\d\d\d\d-\d\d-\d\d)')

# %%
playas['Beach Name'].value_counts()
# Out:
# Tropical Beach                                     133
# Muelle de Arecibo                                  124
# Playa Guayanés                                     113
# Balneario de Patillas                              111
# Playa Moja Casabe                                  102
# Balneario Punta Santiago                           101
# Balneario de Rincón                                101
# Balneario Punta Guilarte                           101
# Pico de Piedra                                     101
# Balneario de Añasco or Balneario Tres Hermanos     100
# Balneario de Puerto Nuevo                           99
# Playa Buyé                                          99
# Balneario Manuel “Nolo” Morales or Sardinera        98
# Villa Lamela                                        96
# Balneario Seven Seas                                95
# Balneario Crash Boat                                95
# Balneario Punta Salinas                             95
# Vacía Talega                                        94
# Playa Santa                                         94
# Balneario de Boquerón                               92
# Playa El Alambique                                  91
# Playa Sixto Escobar                                 91
# Playa el Combate                                    91
# Balneario Cerro Gordo or Javier Calderón Nieves     91
# Playita Rosada                                      91
# Ocean Park                                          90
# Balneario El Escambrón                              88
# Balneario La Monserrate                             88
# Balneario de Carolina                               87
# Caña Gorda                                          87
# Balneario de Salinas                                86
# Playa Azul                                          85
# Playita del Condado                                 85
# Mar Chiquita                                        84
# Playa Cabullón                                      52
# Balneario Sun Bay                                   38
# Playa del Hilton                                    36
# Playa Jauca                                         26
# Playa Flamenco                                       5
# Playa Pelicano                                       4
# Playa Pelícano                                       2
# Playa Guayanés                                       1
# Balneario Manuel "Nolo" Morales or Sardinera         1
# Balneario Punta Guilare                              1
#  Villa Lamela                                        1
# Name: Beach Name, dtype: int64

# %%
import re

# %%
playas['Enterococcus\r\n (colonies/100 mL)']=playas['Enterococcus\r\n (colonies/100 mL)'].fillna(0)

# %%
playas['Enterococcus\r\n (colonies/100 mL)']=playas['Enterococcus\r\n (colonies/100 mL)'].str.extract(r'<?(.*)')

# %%
playas['Enterococcus\r\n (colonies/100 mL)'].describe()
# Out:
# count     3445
# unique     352
# top         10
# freq      1452
# Name: Enterococcus\r\n (colonies/100 mL), dtype: object

# %%
playas['Enterococcus\r\n (colonies/100 mL)']=pd.to_numeric(playas['Enterococcus\r\n (colonies/100 mL)'], errors='coerce')

# %%
# Under the Puerto Rican Enviromental Authorities, Enterococci concentrations  for  a  single  sample  
#shall  not  exceed  70 Colony  Forming  Units  (CFUs)  per 100  mL 
#El parámetro de enterococos excede el "Beach Action Value" aplicable cuando:
#El resultado del análisis bacteriológico es mayor de 70 colonias por cada 100 mililitros de agua (colonias /100mL).

playas_sucias = playas[playas['Enterococcus\r\n (colonies/100 mL)'] > 70]
playas_sucias.shape
# Out:
# (552, 11)

# %%
playas_sucias['Date']=pd.to_datetime(playas_sucias['Date'],format='%Y-%m-%d')
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
playas_sucias.columns
# Out:
# Index(['Date', 'Beach ID', 'Beach Name', 'Latitude', 'Longitude',
#        'Sampling Route', 'Sampling Type', 'Enterococcus\r\n (colonies/100 mL)',
#        'Temperature\r\n(°C)', 'pH ', 'Observations'],
#       dtype='object')

# %%
playas_sucias['Year'] = playas_sucias['Date'].dt.year
playas_sucias['Month'] = playas_sucias['Date'].dt.month
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\AppData\Local\Programs\Python\Python36-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
playas_sucias=playas_sucias.rename(columns={'Enterococcus\r\n (colonies/100 mL)':'Enterococcus_colonies'})
playas_sucias
# Out:
#            Date Beach ID                                      Beach Name  \
# 387  2015-05-04    RW-10                                     Playa Santa
# 411  2015-05-05    RW-31                                  Tropical Beach
# 419  2015-05-11    RW-31                                  Tropical Beach
# 420  2015-05-11    RW-10                                     Playa Santa
# 443  2015-05-19    RW-28                              Playa El Alambique
# 446  2015-05-19    RW-38                               Muelle de Arecibo
# 470  2015-06-01    RW-10                                     Playa Santa
# 475  2015-06-01    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 476  2015-06-01     RW-5                             Balneario de Rincón
# 477  2015-06-01    RW-22                                  Pico de Piedra
# 489  2015-06-02     RW-6                           Balneario de Patillas
# 490  2015-06-02    RW-30                                  Playa Guayanés
# 492  2015-06-02    RW-31                                  Tropical Beach
# 496  2015-06-02    RW-38                               Muelle de Arecibo
# 501  2015-06-08     RW-7                        Balneario Punta Guilarte
# 512  2015-06-15    RW-10                                     Playa Santa
# 526  2015-06-16    RW-38                               Muelle de Arecibo
# 548  2015-06-22     RW-6                           Balneario de Patillas
# 549  2015-06-22     RW-8                                     Playa Buyé
# 550  2015-06-22    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 551  2015-06-22    RW-38                               Muelle de Arecibo
# 553  2015-06-30     RW-6                           Balneario de Patillas
# 556  2015-06-30    RW-31                                  Tropical Beach
# 587  2015-06-30    RW-29                                    Vacía Talega
# 592  2015-07-06     RW-6                           Balneario de Patillas
# 596  2015-07-06    RW-35                                     Playa Jauca
# 605  2015-07-13    RW-34                                Playa del Hilton
# 610  2015-07-13    RW-22                                  Pico de Piedra
# 622  2015-07-14     RW-6                           Balneario de Patillas
# 629  2015-07-14    RW-38                               Muelle de Arecibo
# ...         ...      ...                                             ...
# 3239 2018-10-01   RW-14A                               Playa Moja Casabe
# 3241 2018-10-01    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 3244 2018-10-01    RW-16                            Balneario Crash Boat
# 3245 2018-10-02    RW-38                               Muelle de Arecibo
# 3249 2018-10-09    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 3251 2018-10-09    RW-38                               Muelle de Arecibo
# 3252 2018-10-09   RW-14A                               Playa Moja Casabe
# 3254 2018-10-16    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 3265 2018-10-16    RW-30                                  Playa Guayanés
# 3266 2018-10-16     RW-4                        Balneario Punta Santiago
# 3267 2018-10-16    RW-31                                  Tropical Beach
# 3268 2018-10-16     RW-2                            Balneario Seven Seas
# 3285 2018-10-16    RW-38                               Muelle de Arecibo
# 3288 2018-10-16    RW-30                                  Playa Guayanés
# 3296 2018-10-30    RW-19                         Balneario Punta Salinas
# 3305 2018-10-30     RW-6                           Balneario de Patillas
# 3326 2018-10-30    RW-38                               Muelle de Arecibo
# 3332 2018-11-05    RW-38                               Muelle de Arecibo
# 3333 2018-11-14    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 3342 2018-11-14     RW-7                        Balneario Punta Guilarte
# 3344 2018-11-14    RW-30                                  Playa Guayanés
# 3345 2018-11-14     RW-4                        Balneario Punta Santiago
# 3364 2018-11-14    RW-38                               Muelle de Arecibo
# 3365 2018-11-14    RW-39                                    Mar Chiquita
# 3371 2018-11-20     RW-7                        Balneario Punta Guilarte
# 3372 2018-11-20    RW-30                                  Playa Guayanés
# 3373 2018-11-20     RW-4                        Balneario Punta Santiago
# 3374 2018-11-20    RW-31                                  Tropical Beach
# 3382 2018-11-27   RW-21C                           Balneario de Carolina
# 3424 2018-12-11    RW-31                                  Tropical Beach
#
#         Latitude    Longitude                  Sampling Route Sampling Type  \
# 387   17.9377111  -66.9551972        Route 3: Lajas - Salinas       Routine
# 411   18.1869278  -65.7259667      Route 2: Arroyo - Luquillo       Routine
# 419   18.1869278  -65.7259667      Route 2: Arroyo - Luquillo   Re-sampling
# 420   17.9377111  -66.9551972        Route 3: Lajas - Salinas   Re-sampling
# 443   18.4440917  -66.0221500         Route 1: Dorado - Loíza       Routine
# 446   18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 470   17.9377111  -66.9551972        Route 3: Lajas - Salinas       Routine
# 475   18.2879972  -67.1939222     Route 5: Añasco - Aguadilla       Routine
# 476   18.3409250  -67.2560056     Route 5: Añasco - Aguadilla       Routine
# 477   18.3843639  -67.2129889     Route 5: Añasco - Aguadilla       Routine
# 489   17.9739750  -65.9889806      Route 2: Arroyo - Luquillo       Routine
# 490   18.0626944  -65.8191944      Route 2: Arroyo - Luquillo       Routine
# 492   18.1869278  -65.7259667      Route 2: Arroyo - Luquillo       Routine
# 496   18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 501   17.9620417  -66.0400000      Route 2: Arroyo - Luquillo   Re-sampling
# 512   17.9377111  -66.9551972        Route 3: Lajas - Salinas       Routine
# 526   18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 548   17.9739750  -65.9889806      Route 2: Arroyo - Luquillo   Re-sampling
# 549   18.0488722  -67.1986250              Route 4: Cabo Rojo   Re-sampling
# 550   18.2879972  -67.1939222     Route 5: Añasco - Aguadilla   Re-sampling
# 551   18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta    Re-sampling
# 553   17.9739750  -65.9889806      Route 2: Arroyo - Luquillo       Routine
# 556   18.1869278  -65.7259667      Route 2: Arroyo - Luquillo       Routine
# 587   18.4478583  -65.9062306         Route 1: Dorado - Loíza       Routine
# 592   17.9739750  -65.9889806      Route 2: Arroyo - Luquillo   Re-sampling
# 596   17.9598889  -66.3704167        Route 3: Lajas - Salinas   Re-sampling
# 605   17.9692833  -66.6027278        Route 3: Lajas - Salinas       Routine
# 610   18.3843639  -67.2129889     Route 5: Añasco - Aguadilla       Routine
# 622   17.9739750  -65.9889806      Route 2: Arroyo - Luquillo       Routine
# 629   18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# ...          ...          ...                             ...           ...
# 3239  17.9858100  -67.2145900              Route 4: Cabo Rojo       Routine
# 3241  18.2879972  -67.1939222     Route 5: Añasco - Aguadilla       Routine
# 3244  18.4576667  -67.1637778     Route 5: Añasco - Aguadilla       Routine
# 3245  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 3249  18.2879972  -67.1939222     Route 5: Añasco - Aguadilla  Re-sampling
# 3251  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta   Re-sampling
# 3252  17.9858100  -67.2145900              Route 4: Cabo Rojo  Re-sampling
# 3254  18.4746944  -66.2808917         Route 1: Dorado - Loíza       Routine
# 3265  18.0626944  -65.8191944      Route 2: Arroyo - Luquillo       Routine
# 3266  18.1584139  -65.7551861      Route 2: Arroyo - Luquillo       Routine
# 3267  18.1869278  -65.7259667      Route 2: Arroyo - Luquillo       Routine
# 3268  18.3692667  -65.6360722      Route 2: Arroyo - Luquillo       Routine
# 3285  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 3288  18.0626944  -65.8191944      Route 2: Arroyo - Luquillo       Routine
# 3296  18.4716583  -66.1859944         Route 1: Dorado - Loíza       Routine
# 3305  17.9739750  -65.9889806      Route 2: Arroyo - Luquillo       Routine
# 3326  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 3332         NaN          NaN                             NaN           NaN
# 3333  18.4746944  -66.2808917         Route 1: Dorado - Loíza       Routine
# 3342  17.9620417  -66.0400000      Route 2: Arroyo - Luquillo       Routine
# 3344  18.0626944  -65.8191944      Route 2: Arroyo - Luquillo       Routine
# 3345  18.1584139  -65.7551861      Route 2: Arroyo - Luquillo       Routine
# 3364  18.4792583  -66.7004667  Route: 6: Arecibo – Vega Alta        Routine
# 3365  18.4729167  -66.4856556  Route: 6: Arecibo – Vega Alta        Routine
# 3371  17.9620417  -66.0400000      Route 2: Arroyo - Luquillo  Re-sampling
# 3372  18.0626944  -65.8191944      Route 2: Arroyo - Luquillo  Re-sampling
# 3373  18.1584139  -65.7551861      Route 2: Arroyo - Luquillo  Re-sampling
# 3374  18.1869278  -65.7259667      Route 2: Arroyo - Luquillo  Re-sampling
# 3382  18.4459889  -66.0035722         Route 1: Dorado - Loíza       Routine
# 3424  18.1869278  -65.7259667      Route 2: Arroyo - Luquillo       Routine
#
#       Enterococcus_colonies Temperature\r\n(°C)                          pH   \
# 387                   355.0               28.50                          8.1
# 411                    75.0               29.20                    7.88/7.88
# 419                   473.0               27.30  Bacteriological Re-sampling
# 420                   275.0               26.50  Bacteriological Re-sampling
# 443                   313.0               28.90                         8.27
# 446                    86.0               26.90                         8.15
# 470                    86.0               29.70                         8.03
# 475                   158.0               27.30                         8.22
# 476                   571.0               27.50                         8.15
# 477                  4611.0               28.20                          8.1
# 489                   120.0               28.20                         8.14
# 490                   201.0               28.00                         8.02
# 492                    96.0               28.90                    8.14/8.13
# 496                    97.0               28.60                         8.04
# 501                   109.0               28.40  Bacteriological Re-sampling
# 512                   228.0               29.30                         7.96
# 526                    75.0               26.20                         7.99
# 548                    74.0               30.00  Bacteriological Re-sampling
# 549                   120.0               28.20  Bacteriological Re-sampling
# 550                   383.0               27.00  Bacteriological Re-sampling
# 551                   269.0               29.80  Bacteriological Re-sampling
# 553                    86.0               27.50                         7.91
# 556                   189.0               27.90                    8.09/8.09
# 587                    75.0               29.60                         8.18
# 592                    74.0               26.50  Bacteriological Re-sampling
# 596                   328.0               30.30  Bacteriological Re-sampling
# 605                    85.0               29.00                          8.1
# 610                   291.0               29.20                         8.13
# 622                    74.0               28.50                         7.96
# 629                   131.0               27.90                         8.07
# ...                     ...                 ...                          ...
# 3239                   75.0               29.50                         7.96
# 3241                  131.0               30.00                         7.88
# 3244                   74.0               29.50                         8.01
# 3245                  886.0               27.70                         8.28
# 3249                   72.0               29.50                  Re-sampling
# 3251                  218.0               30.30                  Re-sampling
# 3252                   85.0               28.20                  Re-sampling
# 3254                  108.0               27.70                         8.06
# 3265                  528.0               28.70                          8.1
# 3266                  187.0               27.70                         8.13
# 3267                   84.0               27.80                         8.14
# 3268                  109.0               27.50                         8.09
# 3285                  119.0                28.5                         8.21
# 3288                  528.0                28.7                         8.16
# 3296                   82.0                28.6                         8.04
# 3305                  228.0                28.1                         7.96
# 3326                  173.0                27.2                          8.3
# 3332                  187.0                28.7                  Re-sampling
# 3333                   74.0                27.8                         8.12
# 3342                  183.0                27.7                         8.01
# 3344                  988.0                27.9                         8.07
# 3345                  602.0                27.9                         8.15
# 3364                   75.0                27.4                         8.22
# 3365                   96.0                27.7                         8.31
# 3371                   74.0                28.0                  Re-sampling
# 3372                   75.0                28.5                  Re-sampling
# 3373                  148.0                  29                  Re-sampling
# 3374                  166.0                29.5                  Re-sampling
# 3382                  189.0                27.3                         8.36
# 3424                   96.0                27.2                         8.23
#
#      Observations  Year  Month
# 387           NaN  2015      5
# 411           NaN  2015      5
# 419           NaN  2015      5
# 420           NaN  2015      5
# 443           NaN  2015      5
# 446           NaN  2015      5
# 470           NaN  2015      6
# 475           NaN  2015      6
# 476           NaN  2015      6
# 477           NaN  2015      6
# 489           NaN  2015      6
# 490           NaN  2015      6
# 492           NaN  2015      6
# 496           NaN  2015      6
# 501           NaN  2015      6
# 512           NaN  2015      6
# 526           NaN  2015      6
# 548           NaN  2015      6
# 549           NaN  2015      6
# 550           NaN  2015      6
# 551           NaN  2015      6
# 553           NaN  2015      6
# 556           NaN  2015      6
# 587           NaN  2015      6
# 592           NaN  2015      7
# 596           NaN  2015      7
# 605           NaN  2015      7
# 610           NaN  2015      7
# 622           NaN  2015      7
# 629           NaN  2015      7
# ...           ...   ...    ...
# 3239          NaN  2018     10
# 3241          NaN  2018     10
# 3244          NaN  2018     10
# 3245          NaN  2018     10
# 3249          NaN  2018     10
# 3251          NaN  2018     10
# 3252          NaN  2018     10
# 3254          NaN  2018     10
# 3265          NaN  2018     10
# 3266          NaN  2018     10
# 3267          NaN  2018     10
# 3268          NaN  2018     10
# 3285          NaN  2018     10
# 3288          NaN  2018     10
# 3296          NaN  2018     10
# 3305          NaN  2018     10
# 3326          NaN  2018     10
# 3332          NaN  2018     11
# 3333          NaN  2018     11
# 3342          NaN  2018     11
# 3344          NaN  2018     11
# 3345          NaN  2018     11
# 3364          NaN  2018     11
# 3365          NaN  2018     11
# 3371  PRELIMINARY  2018     11
# 3372  PRELIMINARY  2018     11
# 3373  PRELIMINARY  2018     11
# 3374  PRELIMINARY  2018     11
# 3382          NaN  2018     11
# 3424          NaN  2018     12
#
# [552 rows x 13 columns]

# %%
playas_sucias.to_csv('playassucias2015-2018.csv', index=False)

# %%
playas_sucias['Beach Name'].value_counts()
# Out:
# Tropical Beach                                     77
# Muelle de Arecibo                                  53
# Playa Guayanés                                     51
# Balneario de Patillas                              35
# Balneario de Añasco or Balneario Tres Hermanos     24
# Balneario Manuel “Nolo” Morales or Sardinera       23
# Balneario Punta Santiago                           22
# Balneario Punta Guilarte                           21
# Playa Moja Casabe                                  20
# Pico de Piedra                                     18
# Balneario de Puerto Nuevo                          16
# Balneario de Rincón                                14
# Balneario Crash Boat                               14
# Vacía Talega                                       14
# Balneario Seven Seas                               13
# Balneario Punta Salinas                            13
# Playa Buyé                                         13
# Balneario Cerro Gordo or Javier Calderón Nieves    12
# Playa Santa                                        12
# Villa Lamela                                        9
# Playa Sixto Escobar                                 8
# Playa El Alambique                                  7
# Balneario de Salinas                                7
# Playa el Combate                                    6
# Caña Gorda                                          5
# Balneario de Boquerón                               5
# Playa Cabullón                                      5
# Mar Chiquita                                        4
# Ocean Park                                          4
# Balneario El Escambrón                              4
# Playa del Hilton                                    4
# Playita del Condado                                 4
# Balneario La Monserrate                             3
# Balneario de Carolina                               3
# Playa Azul                                          3
# Playita Rosada                                      2
# Balneario Sun Bay                                   2
# Playa Guayanés                                      1
# Playa Jauca                                         1
# Name: Beach Name, dtype: int64

# %% [markdown]
# Now lets save a csv per year.

# %%
playas_sucias2015 = playas_sucias[playas_sucias['Year'].isin(['2015'])] 
playas_sucias2015.to_csv('playas_sucias2015.csv', index = False)

# %%
playas_sucias2016 = playas_sucias[playas_sucias['Year'].isin(['2016'])] 
playas_sucias2016.to_csv('playas_sucias2016.csv', index = False)

# %%
playas_sucias2017 = playas_sucias[playas_sucias['Year'].isin(['2017'])] 
playas_sucias2017.to_csv('playas_sucias2017.csv', index = False)

# %%
playas_sucias2018 = playas_sucias[playas_sucias['Year'].isin(['2018'])] 
playas_sucias2018.to_csv('playas_sucias2018.csv', index = False)

# %%
playas_sucias2018
# Out:
#            Date Beach ID                                      Beach Name  \
# 2450 2018-01-08    RW-29                                    Vacía Talega
# 2452 2018-01-09     RW-6                           Balneario de Patillas
# 2469 2018-01-08    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 2472 2018-01-08    RW-16                            Balneario Crash Boat
# 2473 2018-01-09    RW-38                               Muelle de Arecibo
# 2478 2018-01-16    RW-29                                    Vacía Talega
# 2479 2018-01-17    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 2495 2018-01-23    RW-31                                  Tropical Beach
# 2513 2018-01-23    RW-38                               Muelle de Arecibo
# 2514 2018-01-23    RW-39                                    Mar Chiquita
# 2517 2018-01-29    RW-38                               Muelle de Arecibo
# 2519 2018-01-29    RW-31                                  Tropical Beach
# 2531 2018-02-06    RW-30                                  Playa Guayanés
# 2532 2018-02-06     RW-4                        Balneario Punta Santiago
# 2533 2018-02-06    RW-31                                  Tropical Beach
# 2551 2018-02-05    RW-38                               Muelle de Arecibo
# 2556 2018-02-12    RW-30                                  Playa Guayanés
# 2557 2018-02-12     RW-4                        Balneario Punta Santiago
# 2563 2018-02-20    RW-26                             Playita del Condado
# 2567 2018-02-20    RW-29                                    Vacía Talega
# 2570 2018-02-21    RW-30                                  Playa Guayanés
# 2590 2018-02-21    RW-38                               Muelle de Arecibo
# 2596 2018-02-26    RW-38                               Muelle de Arecibo
# 2598 2018-03-19    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 2607 2018-03-19     RW-7                        Balneario Punta Guilarte
# 2662 2018-04-04     RW-7                        Balneario Punta Guilarte
# 2664 2018-04-04    RW-30                                  Playa Guayanés
# 2672 2018-04-17    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 2673 2018-04-17    RW-19                         Balneario Punta Salinas
# 2683 2018-04-17    RW-30                                  Playa Guayanés
# ...         ...      ...                                             ...
# 3239 2018-10-01   RW-14A                               Playa Moja Casabe
# 3241 2018-10-01    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 3244 2018-10-01    RW-16                            Balneario Crash Boat
# 3245 2018-10-02    RW-38                               Muelle de Arecibo
# 3249 2018-10-09    RW-15  Balneario de Añasco or Balneario Tres Hermanos
# 3251 2018-10-09    RW-38                               Muelle de Arecibo
# 3252 2018-10-09   RW-14A                               Playa Moja Casabe
# 3254 2018-10-16    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 3265 2018-10-16    RW-30                                  Playa Guayanés
# 3266 2018-10-16     RW-4                        Balneario Punta Santiago
# 3267 2018-10-16    RW-31                                  Tropical Beach
# 3268 2018-10-16     RW-2                            Balneario Seven Seas
# 3285 2018-10-16    RW-38                               Muelle de Arecibo
# 3288 2018-10-16    RW-30                                  Playa Guayanés
# 3296 2018-10-30    RW-19                         Balneario Punta Salinas
# 3305 2018-10-30     RW-6                           Balneario de Patillas
# 3326 2018-10-30    RW-38                               Muelle de Arecibo
# 3332 2018-11-05    RW-38                               Muelle de Arecibo
# 3333 2018-11-14    RW-18    Balneario Manuel “Nolo” Morales or Sardinera
# 3342 2018-11-14     RW-7                        Balneario Punta Guilarte
# 3344 2018-11-14    RW-30                                  Playa Guayanés
# 3345 2018-11-14     RW-4                        Balneario Punta Santiago
# 3364 2018-11-14    RW-38                               Muelle de Arecibo
# 3365 2018-11-14    RW-39                                    Mar Chiquita
# 3371 2018-11-20     RW-7                        Balneario Punta Guilarte
# 3372 2018-11-20    RW-30                                  Playa Guayanés
# 3373 2018-11-20     RW-4                        Balneario Punta Santiago
# 3374 2018-11-20    RW-31                                  Tropical Beach
# 3382 2018-11-27   RW-21C                           Balneario de Carolina
# 3424 2018-12-11    RW-31                                  Tropical Beach
#
#                 Latitude           Longitude                  Sampling Route  \
# 2450          18.4478583         -65.9062306         Route 1: Dorado - Loíza
# 2452           17.973975         -65.9889806      Route 2: Arroyo - Luquillo
# 2469          18.2879972         -67.1939222     Route 5: Añasco - Aguadilla
# 2472  18.457666699999997  -67.16377779999999     Route 5: Añasco - Aguadilla
# 2473          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2478          18.4478583         -65.9062306         Route 1: Dorado - Loíza
# 2479          18.2879972         -67.1939222     Route 5: Añasco - Aguadilla
# 2495  18.186927800000003         -65.7259667      Route 2: Arroyo - Luquillo
# 2513          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2514          18.4729167         -66.4856556  Route: 6: Arecibo – Vega Alta
# 2517          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2519  18.186927800000003         -65.7259667      Route 2: Arroyo - Luquillo
# 2531  18.062694399999998         -65.8191944      Route 2: Arroyo - Luquillo
# 2532          18.1584139         -65.7551861      Route 2: Arroyo - Luquillo
# 2533  18.186927800000003         -65.7259667      Route 2: Arroyo - Luquillo
# 2551          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2556  18.062694399999998         -65.8191944      Route 2: Arroyo - Luquillo
# 2557          18.1584139         -65.7551861      Route 2: Arroyo - Luquillo
# 2563          18.4611306         -66.0824083         Route 1: Dorado - Loíza
# 2567          18.4478583         -65.9062306         Route 1: Dorado - Loíza
# 2570  18.062694399999998         -65.8191944      Route 2: Arroyo - Luquillo
# 2590          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2596          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 2598          18.4746944         -66.2808917         Route 1: Dorado - Loíza
# 2607          17.9620417              -66.04      Route 2: Arroyo - Luquillo
# 2662          17.9620417              -66.04      Route 2: Arroyo - Luquillo
# 2664  18.062694399999998         -65.8191944      Route 2: Arroyo - Luquillo
# 2672          18.4746944         -66.2808917         Route 1: Dorado - Loíza
# 2673          18.4716583         -66.1859944         Route 1: Dorado - Loíza
# 2683  18.062694399999998         -65.8191944      Route 2: Arroyo - Luquillo
# ...                  ...                 ...                             ...
# 3239          17.9858100         -67.2145900              Route 4: Cabo Rojo
# 3241          18.2879972         -67.1939222     Route 5: Añasco - Aguadilla
# 3244          18.4576667         -67.1637778     Route 5: Añasco - Aguadilla
# 3245          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 3249          18.2879972         -67.1939222     Route 5: Añasco - Aguadilla
# 3251          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 3252          17.9858100         -67.2145900              Route 4: Cabo Rojo
# 3254          18.4746944         -66.2808917         Route 1: Dorado - Loíza
# 3265          18.0626944         -65.8191944      Route 2: Arroyo - Luquillo
# 3266          18.1584139         -65.7551861      Route 2: Arroyo - Luquillo
# 3267          18.1869278         -65.7259667      Route 2: Arroyo - Luquillo
# 3268          18.3692667         -65.6360722      Route 2: Arroyo - Luquillo
# 3285          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 3288          18.0626944         -65.8191944      Route 2: Arroyo - Luquillo
# 3296          18.4716583         -66.1859944         Route 1: Dorado - Loíza
# 3305          17.9739750         -65.9889806      Route 2: Arroyo - Luquillo
# 3326          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 3332                 NaN                 NaN                             NaN
# 3333          18.4746944         -66.2808917         Route 1: Dorado - Loíza
# 3342          17.9620417         -66.0400000      Route 2: Arroyo - Luquillo
# 3344          18.0626944         -65.8191944      Route 2: Arroyo - Luquillo
# 3345          18.1584139         -65.7551861      Route 2: Arroyo - Luquillo
# 3364          18.4792583         -66.7004667  Route: 6: Arecibo – Vega Alta
# 3365          18.4729167         -66.4856556  Route: 6: Arecibo – Vega Alta
# 3371          17.9620417         -66.0400000      Route 2: Arroyo - Luquillo
# 3372          18.0626944         -65.8191944      Route 2: Arroyo - Luquillo
# 3373          18.1584139         -65.7551861      Route 2: Arroyo - Luquillo
# 3374          18.1869278         -65.7259667      Route 2: Arroyo - Luquillo
# 3382          18.4459889         -66.0035722         Route 1: Dorado - Loíza
# 3424          18.1869278         -65.7259667      Route 2: Arroyo - Luquillo
#
#      Sampling Type  Enterococcus_colonies Temperature\r\n(°C)          pH   \
# 2450       Routine                  213.0                26.9         8.16
# 2452       Routine                   74.0                25.3         7.94
# 2469       Routine                   85.0                27.2         8.12
# 2472       Routine                  250.0                27.5    8.20/8.20
# 2473       Routine                  156.0                27.2         8.27
# 2478   RE-sampling                  109.0                26.5  RE-sampling
# 2479   RE-sampling                 2613.0                  25  RE-sampling
# 2495       Routine                   74.0                26.9    8.12/8.13
# 2513       Routine                  373.0                25.3         8.31
# 2514       Routine                  246.0                26.8         8.19
# 2517   RE-sampling                  404.0                  24  RE-sampling
# 2519   RE-sampling                 2098.0                  25  RE-sampling
# 2531       Routine                   75.0                26.2         8.12
# 2532       Routine                  122.0                25.6         8.13
# 2533       Routine                  166.0                25.6          8.4
# 2551       Routine                  408.0                24.8         8.18
# 2556   Re-sampling                  131.0                24.2  RE-sampling
# 2557   Re-sampling                   74.0                  24  RE-sampling
# 2563       Routine                   86.0                25.3         8.22
# 2567       Routine                  107.0                26.1         8.25
# 2570       Routine                   74.0                24.9         8.04
# 2590       Routine                 1674.0                24.7         8.07
# 2596   RE-sampling                 1850.0                  23  RE-sampling
# 2598       Routine                 1464.0                24.9         8.06
# 2607       Routine                   75.0                  27          NaN
# 2662       Routine                   72.0                27.1         8.06
# 2664       Routine                  122.0                28.2         8.03
# 2672       Routine                  256.0                26.5         7.98
# 2673       Routine                   71.0                26.4         8.04
# 2683       Routine                 1187.0                27.5         8.11
# ...            ...                    ...                 ...          ...
# 3239       Routine                   75.0               29.50         7.96
# 3241       Routine                  131.0               30.00         7.88
# 3244       Routine                   74.0               29.50         8.01
# 3245       Routine                  886.0               27.70         8.28
# 3249  Re-sampling                    72.0               29.50  Re-sampling
# 3251  Re-sampling                   218.0               30.30  Re-sampling
# 3252  Re-sampling                    85.0               28.20  Re-sampling
# 3254       Routine                  108.0               27.70         8.06
# 3265       Routine                  528.0               28.70          8.1
# 3266       Routine                  187.0               27.70         8.13
# 3267       Routine                   84.0               27.80         8.14
# 3268       Routine                  109.0               27.50         8.09
# 3285       Routine                  119.0                28.5         8.21
# 3288       Routine                  528.0                28.7         8.16
# 3296       Routine                   82.0                28.6         8.04
# 3305       Routine                  228.0                28.1         7.96
# 3326       Routine                  173.0                27.2          8.3
# 3332           NaN                  187.0                28.7  Re-sampling
# 3333       Routine                   74.0                27.8         8.12
# 3342       Routine                  183.0                27.7         8.01
# 3344       Routine                  988.0                27.9         8.07
# 3345       Routine                  602.0                27.9         8.15
# 3364       Routine                   75.0                27.4         8.22
# 3365       Routine                   96.0                27.7         8.31
# 3371  Re-sampling                    74.0                28.0  Re-sampling
# 3372  Re-sampling                    75.0                28.5  Re-sampling
# 3373  Re-sampling                   148.0                  29  Re-sampling
# 3374  Re-sampling                   166.0                29.5  Re-sampling
# 3382       Routine                  189.0                27.3         8.36
# 3424       Routine                   96.0                27.2         8.23
#
#      Observations  Year  Month
# 2450          NaN  2018      1
# 2452          NaN  2018      1
# 2469          NaN  2018      1
# 2472          NaN  2018      1
# 2473          NaN  2018      1
# 2478          NaN  2018      1
# 2479          NaN  2018      1
# 2495          NaN  2018      1
# 2513          NaN  2018      1
# 2514          NaN  2018      1
# 2517          NaN  2018      1
# 2519          NaN  2018      1
# 2531          NaN  2018      2
# 2532          NaN  2018      2
# 2533          NaN  2018      2
# 2551          NaN  2018      2
# 2556          NaN  2018      2
# 2557          NaN  2018      2
# 2563          NaN  2018      2
# 2567          NaN  2018      2
# 2570          NaN  2018      2
# 2590          NaN  2018      2
# 2596          NaN  2018      2
# 2598          NaN  2018      3
# 2607          NaN  2018      3
# 2662          NaN  2018      4
# 2664          NaN  2018      4
# 2672          NaN  2018      4
# 2673          NaN  2018      4
# 2683          NaN  2018      4
# ...           ...   ...    ...
# 3239          NaN  2018     10
# 3241          NaN  2018     10
# 3244          NaN  2018     10
# 3245          NaN  2018     10
# 3249          NaN  2018     10
# 3251          NaN  2018     10
# 3252          NaN  2018     10
# 3254          NaN  2018     10
# 3265          NaN  2018     10
# 3266          NaN  2018     10
# 3267          NaN  2018     10
# 3268          NaN  2018     10
# 3285          NaN  2018     10
# 3288          NaN  2018     10
# 3296          NaN  2018     10
# 3305          NaN  2018     10
# 3326          NaN  2018     10
# 3332          NaN  2018     11
# 3333          NaN  2018     11
# 3342          NaN  2018     11
# 3344          NaN  2018     11
# 3345          NaN  2018     11
# 3364          NaN  2018     11
# 3365          NaN  2018     11
# 3371  PRELIMINARY  2018     11
# 3372  PRELIMINARY  2018     11
# 3373  PRELIMINARY  2018     11
# 3374  PRELIMINARY  2018     11
# 3382          NaN  2018     11
# 3424          NaN  2018     12
#
# [133 rows x 13 columns]

# %%
df= playas_sucias2018.sort_values(by='Enterococcus_colonies',ascending=False).head(15)
ax= df.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='#fdbb84')
ax.set_title("Bacteria samples exceeding the Beach Action Value", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
ax.patches
for i,bar in enumerate(ax.patches):
    value= int(round(bar.get_width()))
    x_pos= bar.get_width() - 1
    y_pos=i
    ax.text(x_pos,y_pos,value,verticalalignment='center',ha='right',color='grey')
# plt.gcf().text(0.5, 0.85, "Beaches with bacteria samples exceeding Puerto Rico's Environmental Quality Board this year", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig('Samples2018.pdf',transparent=True)
plt.show()

# %%
playas_sucias2015NOV= playas_sucias2015[playas_sucias2015['Month']>=11]
playas_sucias2015NOV.to_csv('playas_sucias2015NOV.csv', index = False)

# %%
playas_sucias2016NOV = playas_sucias2016[playas_sucias2016['Month']>=11]
playas_sucias2016NOV.to_csv('playas_sucias2016NOV.csv', index = False)

# %%
playas_sucias2016NOV['Enterococcus_colonies'].value_counts(ascending=False)
# Out:
# 226.0      2
# 146.0      2
# 243.0      2
# 122.0      2
# 187.0      2
# 4611.0     1
# 465.0      1
# 24196.0    1
# 195.0      1
# 73.0       1
# 82.0       1
# 221.0      1
# 171.0      1
# 813.0      1
# 1785.0     1
# 145.0      1
# 110.0      1
# 754.0      1
# 417.0      1
# 1951.0     1
# 108.0      1
# 484.0      1
# 102.0      1
# 121.0      1
# 75.0       1
# 2489.0     1
# 1780.0     1
# 109.0      1
# 345.0      1
# 203.0      1
# 2105.0     1
# 2282.0     1
# 84.0       1
# 384.0      1
# 86.0       1
# 175.0      1
# 1624.0     1
# 120.0      1
# 96.0       1
# 161.0      1
# 528.0      1
# 132.0      1
# 337.0      1
# 341.0      1
# 169.0      1
# Name: Enterococcus_colonies, dtype: int64

# %%
playas_sucias2017NOV= playas_sucias2017[playas_sucias2017['Month']>=11]
playas_sucias2017NOV.to_csv('playas_sucias2017NOV.csv', index = False)

# %%
playas_sucias2018NOV= playas_sucias2018[playas_sucias2018['Month']>=11]
playas_sucias2018NOV.to_csv('playas_sucias2018NOV.csv', index = False)

# %%
playas_sucias2015['Month'].value_counts()
# Out:
# 11    22
# 9     18
# 6     18
# 10    15
# 8     13
# 7     10
# 12     6
# 5      6
# Name: Month, dtype: int64

# %%
#Water conditions after the hurricane. I must point out that the JCA did not take samples until Nov 27. 
#The hurricane hit on Sept 20th. 
Maria_year= playas_sucias[(playas_sucias['Year']==2017) & (playas_sucias['Month']>=11)]

# %%
df1= Maria_year.sort_values(by='Month',ascending=False).head(20)
ax= df1.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Beach Water Quality in Puerto Rico after Maria in 2017", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
#plt.gcf().text(0.5, 0.91, "Bacteria samples exceeding Puerto Rico's Environmental Quality Board parameters", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
#plt.savefig('BeachWaterQualityafterMaria.pdf',transparent=True)
plt.show()

# %%
playas_sucias.dtypes
# Out:
# Date                     datetime64[ns]
# Beach ID                         object
# Beach Name                       object
# Latitude                         object
# Longitude                        object
# Sampling Route                   object
# Sampling Type                    object
# Enterococcus_colonies           float64
# Temperature\r\n(°C)              object
# pH                               object
# Observations                     object
# Year                              int64
# Month                             int64
# dtype: object

# %%
df= playas_sucias.sort_values(by='Enterococcus_colonies',ascending=False).head(15)
ax= df.plot(kind='barh', x='Beach Name', y='Enterococcus_colonies', figsize=(10,5),legend=False,rot=0,color='mediumaquamarine')
ax.set_title("Overall Beach Water Quality in Puerto Rico from 2015", pad=30, fontsize=24)
ax.set_xlabel('Enterococci Count (MPN/100mL)')
ax.patches
for i,bar in enumerate(ax.patches):
    value= int(round(bar.get_width()))
    x_pos= bar.get_width() - 1
    y_pos=i
    ax.text(x_pos,y_pos,value,verticalalignment='center',ha='right',color='grey')
plt.gcf().text(0.5, 0.85, "Beaches with bacteria samples exceeding Puerto Rico's Environmental Quality Board parameters from October 2015 to Present", ha='center', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig('Overall Beach Water Quality in Puerto Rico from 2015.pdf',transparent=True)
plt.show()

# %%
playas_sucias.groupby('Beach Name').Enterococcus_colonies.max()
# Out:
# Beach Name
# Balneario Cerro Gordo or Javier Calderón Nieves      631.0
# Balneario Crash Boat                                 452.0
# Balneario El Escambrón                               331.0
# Balneario La Monserrate                              327.0
# Balneario Manuel “Nolo” Morales or Sardinera        2105.0
# Balneario Punta Guilarte                             465.0
# Balneario Punta Salinas                              368.0
# Balneario Punta Santiago                            4884.0
# Balneario Seven Seas                                 828.0
# Balneario Sun Bay                                    109.0
# Balneario de Añasco or Balneario Tres Hermanos      4611.0
# Balneario de Boquerón                                724.0
# Balneario de Carolina                                189.0
# Balneario de Patillas                               6294.0
# Balneario de Puerto Nuevo                           2282.0
# Balneario de Rincón                                  813.0
# Balneario de Salinas                                 309.0
# Caña Gorda                                           341.0
# Mar Chiquita                                        1616.0
# Muelle de Arecibo                                  24196.0
# Ocean Park                                           379.0
# Pico de Piedra                                      5475.0
# Playa Azul                                          2489.0
# Playa Buyé                                          6131.0
# Playa Cabullón                                       550.0
# Playa El Alambique                                   650.0
# Playa Guayanés                                     24196.0
# Playa Guayanés                                       109.0
# Playa Jauca                                          328.0
# Playa Moja Casabe                                   1333.0
# Playa Santa                                         1785.0
# Playa Sixto Escobar                                 5172.0
# Playa del Hilton                                     471.0
# Playa el Combate                                    4352.0
# Playita Rosada                                       168.0
# Playita del Condado                                  293.0
# Tropical Beach                                     24196.0
# Vacía Talega                                        1333.0
# Villa Lamela                                         389.0
# Name: Enterococcus_colonies, dtype: float64

# %%
playas_sucias['Year'] = playas_sucias['Date'].dt.year
playas_sucias['Month'] = playas_sucias['Date'].dt.month

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prefinal= playas_sucias.pivot_table(index="Month",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'ocean'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(prefinal, annot=None, cmap=cmaps)
#plt.tight_layout()
plt.savefig('Dirty_beaches_in_Puerto_Rico_peryear_month.pdf', transparent=True)
plt.show()

# %%
final = playas_sucias.pivot_table(index="Beach Name",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'ocean'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(final, annot=None, cmap=cmaps)
#plt.tight_layout()
plt.savefig('Dirty_beaches_in_Puerto_Rico.pdf', transparent=True)
plt.show()

# %%
df=pd.read_csv('Most visited beaches')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-1b62c34444c7> in <module>()
# ----> 1 df=pd.read_csv('Most visited beaches')
#       2 df
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Most visited beaches' does not exist

# %%
#Mergin two different data frames to seethe conditions of the most visited beaches
most_visited= playas_sucias[playas_sucias['Beach Name'].isin(['Playita del Condado','Balneario de Carolina',
                                                              'Balneario de Boquerón','Playa Buyé','Balneario El Escambrón',
                                                              'Balneario Seven Seas',
                                                              'Balneario La Monserrate',
                                                              'Ocean Park',
                                                              'Playa el Combate','Balneario Crash Boat'])] 
most_visited

# %%
df2 = most_visited.pivot_table(index="Beach Name",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'ocean'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(df2, annot=None, cmap=cmaps)
plt.tight_layout()
#plt.savefig('Dirty most visited beaches per year.pdf', transparent=True)
plt.show()

# %%
df2 = most_visited.pivot_table(index="Month",columns="Year",values="Enterococcus_colonies", aggfunc="mean").fillna(0)
plt.figure(figsize=(5, 8))
cmaps = 'ocean'
#gradient = np.linspace(0, 1, 256)
#gradient = np.vstack((gradient, gradient))
sns.heatmap(df2, annot=None, cmap=cmaps)
plt.tight_layout()
#plt.savefig('Dirtymostvisitedbeachesperyearandmonth.pdf', transparent=True)
plt.show()
